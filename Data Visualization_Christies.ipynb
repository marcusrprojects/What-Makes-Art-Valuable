# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
ArtInfo = pd.read_csv ('Christies_Art_Objects_Clean.csv')

# %%
ArtInfo.sort_values('price', ascending=False).head(50)
# Out:
#                     Artist  Birth  Death  Age  Alive? popularity  \
# 606       jackson pollock    1912   1956   44       0    112,000
# 1738         lucian freud    1922   2011   89       0    351,000
# 761            cy twombly    1928   2011   83       0     53,100
# 494           franz kline    1910   1962   52       0    255,000
# 2447     roy lichtenstein    1923   1997   74       0          0
# 1639   richard diebenkorn    1922   1993   71       0     66,300
# 2486     roy lichtenstein    1923   1997   74       0          0
# 584             joan miró    1893   1983   90       0    999,000
# 0          pierre bonnard    1867   1947   80       0    114,000
# 467          lucian freud    1922   2011   89       0    351,000
# 1383           cy twombly    1928   2011   83       0     53,100
# 631          lucian freud    1922   2011   89       0    351,000
# 2044        pablo picasso    1881   1973   92       0          0
# 1748        francis bacon    1909   1992   83       0    567,000
# 2568        pablo picasso    1881   1973   92       0          0
# 476         edward hopper    1882   1967   85       0    255,000
# 505          agnes martin    1912   2004   92       0     31,300
# 722     willem de kooning    1904   1997   93       0     49,700
# 415           mark rothko    1903   1970   67       0    489,000
# 557           andy warhol    1928   1987   59       0  3,340,000
# 2113        fernand léger    1881   1955   74       0          0
# 1019       arthur g. dove    1880   1946   66       0    609,000
# 1536     vincent van gogh    1853   1890   37       0    523,000
# 2550   richard diebenkorn    1922   1993   71       0          0
# 902         rené magritte    1898   1967   69       0    551,000
# 365         henri matisse    1869   1954   85       0    253,000
# 1115        francis bacon    1909   1992   83       0    567,000
# 1557          frida kahlo    1907   1954   47       0  2,610,000
# 364          claude monet    1840   1926   86       0    309,000
# 2376          david smith    1906   1965   59       0          0
# 191          claude monet    1840   1926   86       0    309,000
# 1718       arthur g. dove    1880   1946   66       0    609,000
# 55          joan mitchell    1925   1992   67       0    119,000
# 731      alexander calder    1898   1976   78       0    156,000
# 1440         agnes martin    1912   2004   92       0     31,300
# 1377        kazuo shiraga    1924   2008   84       0     20,800
# 264         fernand léger    1881   1955   74       0    298,000
# 1795      gerhard richter    1932      0   90       1     69,700
# 1220  maurice de vlaminck    1876   1958   82       0     68,100
# 167         david hockney    1937      0   85       1    190,000
# 297         david hockney    1937      0   85       1    190,000
# 704         lucio fontana    1899   1968   69       0    138,000
# 78          pablo picasso    1881   1973   92       0    475,000
# 1766        lucio fontana    1899   1968   69       0    140,000
# 288      alexander calder    1898   1976   78       0    156,000
# 69           claude monet    1840   1926   86       0    309,000
# 2489      francis picabia    1879   1953   74       0          0
# 1628     alexander calder    1898   1976   78       0    155,000
# 1009          andy warhol    1928   1987   59       0  3,340,000
# 855           andy warhol    1928   1987   59       0  3,340,000
#
#                                               Art Title   DoC Currency  \
# 606                                     Number 19, 1948  1948      USD
# 1738                        Benefits Supervisor Resting  1994      USD
# 761                                            Untitled  1969      USD
# 494                                            Untitled  1957      USD
# 2447                                     Seductive Girl  1996      USD
# 1639                                    Ocean Park #126  1984      USD
# 2486                            Nude with Yellow Flower  1994      USD
# 584                                            Peinture     0      USD
# 0                  La Terrasse ou Une terrasse à Grasse     0      USD
# 467                               Girl with Closed Eyes  1986      USD
# 1383                                           Untitled  1971      USD
# 631                                    Julie and Martin  2001      USD
# 2044                                    Homme à la pipe     0      USD
# 1748  Study for Head of Isabel Rawsthorne and George...  1967      USD
# 2568    Femme assise dans un fauteuil noir (Jacqueline)     0      USD
# 476                                        Two Puritans  1945      USD
# 505                                        Orange Grove  1965      USD
# 722                                          Untitled X  1983      USD
# 415                                            Untitled  1961      USD
# 557                                             Flowers  1964      USD
# 2113                                        Composition  1920      USD
# 1019                                             Sunset  1935      USD
# 1536                                         Knotberken     0      USD
# 2550                                     Ocean Park #92  1976      USD
# 902                                 Le miroir universel  1938      USD
# 365                                     Nu à la fenêtre     0      USD
# 1115                                     Man in Blue VI  1954      USD
# 1557                        Portrait of a Lady in White     0      USD
# 364                           Iris jaunes au nuage rose  1924      USD
# 2376                                      Agricola XIII  1953      USD
# 191                                            Pivoines  1887      USD
# 1718                           Boat Going Through Inlet     0      USD
# 55                                             Untitled     0      USD
# 731            Six White Dots Over Blue, Black, and Red  1948      USD
# 1440                                        Untitled II  1982      USD
# 1377                                               BB56  1961      USD
# 264                              La femme à la toilette  1925      USD
# 1795                                           Monstein  1981      USD
# 1220                             Les régates à Bougival  1905      USD
# 167   Great Pyramid at Giza with Broken Head from Th...  1963      USD
# 297                                     California Bank  1964      USD
# 704                           Concetto spaziale, Attese  1961      USD
# 78                              Mandoline sur une table  1922      USD
# 1766                          Concetto spaziale, Attese  1967      USD
# 288                                          White Moon  1955      USD
# 69                            Vue du village de Giverny  1886      USD
# 2489                         Sans titre (Pot de fleurs)     0      USD
# 1628                                           Untitled  1952      USD
# 1009                                  Statue of Liberty  1986      USD
# 855                                   Statue of Liberty  1986      USD
#
#            price  low_estimate  high_estimate  Sold  Est Accuracy  \
# 606   58363750.0    25000000.0     35000000.0     1             1
# 1738  56165000.0    30000000.0     50000000.0     1             1
# 761   42725000.0    35000000.0     55000000.0     1             0
# 494   40402500.0    20000000.0     30000000.0     1             1
# 2447  31525000.0    22000000.0     28000000.0     1             1
# 1639  23937500.0    16000000.0     20000000.0     1             1
# 2486  23643750.0    12000000.0     16000000.0     1             1
# 584   23375000.0    18000000.0     25000000.0     1             0
# 0     19570000.0     5000000.0      8000000.0     1             1
# 467   18968125.0    12500000.0     18750000.0     1             1
# 1383  17525000.0    15000000.0     25000000.0     1             0
# 631   16965000.0    15000000.0     20000000.0     1             0
# 2044  15430000.0    15000000.0     20000000.0     1             0
# 1748  15223125.0    10000000.0     15000000.0     1             1
# 2568  12073750.0     7500000.0     11250000.0     1             1
# 476   11581000.0    10000000.0     15000000.0     1             0
# 505   10693000.0     6500000.0      8500000.0     1             1
# 722    8677000.0     7000000.0      9000000.0     1             0
# 415    8489500.0     2500000.0      3500000.0     1             1
# 557    8411750.0     6000000.0      9000000.0     1             0
# 2113   7804375.0     6250000.0      8750000.0     1             0
# 1019   7802500.0     2000000.0      3000000.0     1             1
# 1536   7344500.0     4000000.0      6000000.0     1             1
# 2550   7067750.0     4000000.0      6000000.0     1             1
# 902    6661000.0     3000000.0      5000000.0     1             1
# 365    6517500.0     7000000.0     10000000.0     1            -1
# 1115   6211562.5     5000000.0      7500000.0     1             0
# 1557   5836500.0     3000000.0      5000000.0     1             1
# 364    5765000.0     6000000.0      8000000.0     1            -1
# 2376   5765000.0     2500000.0      3500000.0     1             1
# 191    5635937.5     4375000.0      6875000.0     1             0
# 1718   5429000.0     2500000.0      3500000.0     1             1
# 55     5399500.0     4000000.0      6000000.0     1             0
# 731    5387750.0     2500000.0      3500000.0     1             1
# 1440   4951500.0     2500000.0      3500000.0     1             1
# 1377   4869000.0     3000000.0      5000000.0     1             0
# 264    4710000.0     1500000.0      2000000.0     1             1
# 1795   4695000.0     5000000.0      7000000.0     1            -1
# 1220   4531562.5     4375000.0      5625000.0     1             0
# 167    4391562.5     3125000.0      4375000.0     1             1
# 297    4285937.5     3750000.0      6250000.0     1             0
# 704    4266250.0     3750000.0      6250000.0     1             0
# 78     4212500.0     4000000.0      6000000.0     1             0
# 1766   4093125.0     3125000.0      4375000.0     1             0
# 288    3973000.0     3500000.0      5000000.0     1             0
# 69     3972500.0     3500000.0      5500000.0     1             0
# 2489   3760937.5     1125000.0      1500000.0     1             1
# 1628   3749000.0     2500000.0      3500000.0     1             1
# 1009   3719500.0     3000000.0      6000000.0     1             0
# 855    3719500.0     3000000.0      6000000.0     1             0
#
#                      Dimentions  close date  \
# 606           (78.4 x 57.4 cm.)        2013
# 1738        (150.5 x 161.2 cm.)        2015
# 761         (200.7 x 239.4 cm.)        2015
# 494         (200.7 x 280.4 cm.)        2012
# 2447          (127 x 182.8 cm.)        2013
# 1639        (236.2 x 205.7 cm.)        2018
# 2486            (233 x 183 cm.)        2013
# 584         (129.8 x 161.9 cm.)        2017
# 0           (125.3 x 134.4 cm.)        2019
# 467            (46.3 x 60.4cm.)        2022
# 1383        (147.6 x 195.8 cm.)        2015
# 631           (122 x 152.2 cm.)        2014
# 2044           (130.1 x 97 cm.)        2021
# 1748           (35.5 x 30.5cm.)        2015
# 2568         (130.4 x 97.8 cm.)        2021
# 476          (76.2 x 101.6 cm.)        2021
# 505         (182.9 x 182.9 cm.)        2016
# 722         (195.6 x 223.5 cm.)        2015
# 415           (60.6 x 45.7 cm.)        2021
# 557           (60.9 x 60.9 cm.)        2013
# 2113            (65 x 54.1 cm.)        2022
# 1019            (70 x 83.8 cm.)        2021
# 1536          (42.8 x 58.6 cm.)        2021
# 2550        (205.7 x 205.7 cm.)        2013
# 902              (116 x 89 cm.)        2015
# 365           (65.3 x 54.5 cm.)        2019
# 1115         (152.7 x 116.8cm.)        2013
# 1557         (118.1 x 81.3 cm.)        2019
# 364         (100.4 x 100.4 cm.)        2015
# 2376  (90.2 x 109.2 x 30.5 cm.)        2015
# 191          (73.7 x 100.3 cm.)        2018
# 1718          (51.4 x 71.8 cm.)        2015
# 55          (194.9 x 185.4 cm.)        2016
# 731   (106.6 x 60.9 x 55.8 cm.)        2013
# 1440        (182.8 x 182.8 cm.)        2017
# 1377         (129.8 x 97.1 cm.)        2014
# 264             (92.1 x 73 cm.)        2021
# 1795            (101 x 151 cm.)        2019
# 1220          (60.5 x 73.5 cm.)        2012
# 167              (183 x 183cm.)        2013
# 297            (76.2 x 63.5cm.)        2018
# 704               (100 x 80cm.)        2017
# 78           (82.2 x 100.4 cm.)        2018
# 1766           (93.2 x 73.5cm.)        2015
# 288     (58.4 x 289.6 x 94 cm.)        2016
# 69              (66 x 81.6 cm.)        2018
# 2489            (65.2 x 54 cm.)        2018
# 1628     (104.8 x 115 x 27 cm.)        2016
# 1009        (182.8 x 182.8 cm.)        2016
# 855         (182.8 x 182.8 cm.)        2016
#
#                                           Auction Title
# 606                POST-WAR & CONTEMPORARY EVENING SALE
# 1738         POST-WAR AND CONTEMPORARY ART EVENING SALE
# 761          POST-WAR AND CONTEMPORARY ART EVENING SALE
# 494            POST-WAR & CONTEMPORARY ART EVENING SALE
# 2447             POST-WAR AND CONTEMPORARY EVENING SALE
# 1639         POST-WAR AND CONTEMPORARY ART EVENING SALE
# 2486               POST-WAR & CONTEMPORARY EVENING SALE
# 584   IMPRESSIONIST & MODERN ART EVENING SALE INCLUD...
# 0             IMPRESSIONIST AND MODERN ART EVENING SALE
# 467              20TH/21ST CENTURY: LONDON EVENING SALE
# 1383             POST-WAR AND CONTEMPORARY EVENING SALE
# 631            POST-WAR & CONTEMPORARY ART EVENING SALE
# 2044                          20TH CENTURY EVENING SALE
# 1748      POST-WAR AND CONTEMPORARY ART EVENING AUCTION
# 2568                          20TH CENTURY EVENING SALE
# 476                           20TH CENTURY EVENING SALE
# 505          POST-WAR AND CONTEMPORARY ART EVENING SALE
# 722          POST-WAR AND CONTEMPORARY ART EVENING SALE
# 415              POST-WAR AND CONTEMPORARY ART DAY SALE
# 557                POST-WAR & CONTEMPORARY EVENING SALE
# 2113             20TH/21ST CENTURY: LONDON EVENING SALE
# 1019                                       AMERICAN ART
# 1536                          20TH CENTURY EVENING SALE
# 2550               POST-WAR & CONTEMPORARY EVENING SALE
# 902               IMPRESSIONIST AND MODERN EVENING SALE
# 365           IMPRESSIONIST AND MODERN ART EVENING SALE
# 1115    POST-WAR AND CONTEMPORARY ART (EVENING AUCTION)
# 1557                                 LATIN AMERICAN ART
# 364               IMPRESSIONIST AND MODERN EVENING SALE
# 2376             POST-WAR AND CONTEMPORARY EVENING SALE
# 191           IMPRESSIONIST AND MODERN ART EVENING SALE
# 1718                                       AMERICAN ART
# 55             POST-WAR & CONTEMPORARY ART EVENING SALE
# 731                POST-WAR & CONTEMPORARY EVENING SALE
# 1440         POST-WAR AND CONTEMPORARY ART EVENING SALE
# 1377           POST-WAR & CONTEMPORARY ART EVENING SALE
# 264                           20TH CENTURY EVENING SALE
# 1795         POST-WAR AND CONTEMPORARY ART EVENING SALE
# 1220              IMPRESSIONIST/MODERN ART EVENING SALE
# 167     POST-WAR AND CONTEMPORARY ART (EVENING AUCTION)
# 297       POST-WAR AND CONTEMPORARY ART EVENING AUCTION
# 704         POST WAR & CONTEMPORARY ART EVENING AUCTION
# 78    IMPRESSIONIST AND MODERN ART EVENING SALE INCL...
# 1766      POST-WAR AND CONTEMPORARY ART EVENING AUCTION
# 288          POST-WAR AND CONTEMPORARY ART EVENING SALE
# 69    IMPRESSIONIST AND MODERN ART EVENING SALE INCL...
# 2489          IMPRESSIONIST AND MODERN ART EVENING SALE
# 1628         POST-WAR AND CONTEMPORARY ART EVENING SALE
# 1009           POST-WAR & CONTEMPORARY ART EVENING SALE
# 855            POST-WAR & CONTEMPORARY ART EVENING SALE

# %% [markdown]
# # Analisis of Auction House Estimates

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.hist(ArtInfo["Est Accuracy"],bins = 3, label = '# of Accurate Estimates',
        histtype='bar', ec='black', color = "steelblue")
ax.set_title("Distribution of Art Estimate Accuracy" , fontsize = 25)
ax.set_xlabel("Accuracy", fontsize = 20)
ax.set_ylabel("# of Artworks", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

plt.show(fig)

# %%
above = 0
bellow = 0
on = 0
for items in ArtInfo["Est Accuracy"]:
    if items == 0:
        on += 1
    elif items == 1:
        above += 1
    else:
        bellow += 1

total = above + on + bellow
        
Accuracy = on / total
per_over = above/ total
per_under = bellow/ total

print("Auction House records have an accuracy of:", round(Accuracy,2), "%")
print("percentage Under Estimated:", round(per_over,2), "%")
print("percentage Over estimated:", round(per_under,2), "%")
# Out:
# Auction House records have an accuracy of: 0.32 %
# percentage Under Estimated: 0.54 %
# percentage Over estimated: 0.14 %

# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([above, bellow, on, 1])
mylabels = ["Under Estimate: " + str(round(per_over,2)), 
            "Over Estimate: " + str(round(per_under,2)), 
            "Accurate Estimate: " + str(round(Accuracy,2)), ""]
myexplode = [0, 0, 0.2, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# # Looking At Corrilations

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.scatter(ArtInfo["high_estimate"], ArtInfo["price"], color = "green", label = 'Sale Vs High Est')
plt.yscale("log")
plt.xscale("log")

ax.set_title("Sale Price Vs Estimate Price" , fontsize = 25)
ax.set_xlabel("High Estimate Price", fontsize = 20)
ax.set_ylabel("Sale Price", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.scatter(ArtInfo["low_estimate"],ArtInfo["price"], color = "blue", label = 'Sale Vs Low Est')
plt.yscale("log")
plt.xscale("log")

ax.set_title("Sale Price Vs Estimate Price" , fontsize = 25)
ax.set_xlabel("Low Estimate Price", fontsize = 20)
ax.set_ylabel("Sale Price", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

# %%
# Created a new data frame with out any duplicate artists to not artificialy inflate the amout of artists born
# in a certain time
Removed_duplicate_Artists = ArtInfo.copy()
Removed_duplicate_Artists.drop_duplicates(subset ="Artist",keep = "first", inplace = True)

# %%
#Artist birth year vs price
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.scatter(Removed_duplicate_Artists["Birth"],Removed_duplicate_Artists["price"], color = "green", 
           label = 'Birth Year Vs Price')
plt.yscale("log")

ax.set_title("Artist Birth Year Vs Art Price" , fontsize = 25)
ax.set_xlabel("Birth Year", fontsize = 20)
ax.set_ylabel("Sale Price", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

# %%
#birth year plot distribution
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.hist(Removed_duplicate_Artists["Birth"],bins = 100, label = '# of Artists',
        histtype='bar', ec='black', color = "steelblue")
ax.set_title("Artist Birth Year Distribution Plot" , fontsize = 25)
ax.set_xlabel("Artist Birth Year", fontsize = 20)
ax.set_ylabel("# Artists", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

plt.show(fig)

# %% [markdown]
# ## Cleaning and plotting popularity vs price

# %%
pop = []
Popularity_df = ArtInfo.copy()
Popularity_df.drop(Popularity_df.index[Popularity_df['popularity'] == "0"], inplace=True)
Popularity_df.head(2000)

for items in Popularity_df['popularity']:
    popularity = items.replace(",", "")
    try:
        popularity_int = int(popularity)
    except:
        popularity_int = 0
    
    pop.append(popularity_int)

Popularity_df['popularity'] = pop

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.scatter(Popularity_df['popularity'],Popularity_df["price"], color = "blue", label = 'popularity Vs Price')
plt.yscale("log")
plt.xscale("log")

ax.set_title("Yahoo Search Popularity Vs Sale Price" , fontsize = 25)
ax.set_xlabel("Popularity", fontsize = 20)
ax.set_ylabel("Sale Price", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

# %% [markdown]
# # Corilation Matrix

# %%
Popularity_df.head(50)
# Out:
#                                                Artist  Birth  Death  Age  \
# 0                                     pierre bonnard    1867   1947   80
# 1                                      antonio saura    1930   1998   68
# 2                                      pablo picasso    1881   1973   92
# 3                                 yves saint laurent    1936   2008   72
# 4                                       yayoi kusama    1929      0   93
# 5                                       vito acconci    1940      0   82
# 6                           lucian freud, o.m., c.h.    1922   2011   89
# 7                                robert rauschenberg    1925   2008   83
# 8                                       marc chagall    1887   1985   98
# 9                                      salvador dalí    1904   1989   85
# 10                                     hector trotin    1894   1966   72
# 11                                   fernando botero    1932      0   90
# 12  hodges, william . early issues of the engraved...   1744   1797   53
# 13                                       andy warhol    1928   1987   59
# 14                                         on kawara    1932   2014   82
# 15                                      george condo    1957      0   65
# 16                                    georges braque    1882   1963   81
# 17                                    richard avedon    1923   2004   81
# 18                                      milton avery    1885   1965   80
# 19                                         vik muniz    1961      0   61
# 20                                     henri matisse    1869   1954   85
# 21                      laurence stephen lowry, r.a.    1887   1976   89
# 22                                   paulina olowska    1976      0   46
# 23                                   julian schnabel    1951      0   71
# 24                                          otto dix    1891   1969   78
# 25                                  louis marcoussis    1883   1941   58
# 26                                  alexander calder    1898   1976   78
# 27                                     salvador dalí    1904   1989   85
# 28                                      garth weiser    1979      0   43
# 29                                      larry rivers    1923   2002   79
# 30                                  john piper, c.h.    1903   1992   89
# 31                                    ernest procter    1886   1935   49
# 32                                   fernando botero    1932      0   90
# 33                                     pablo picasso    1881   1973   92
# 34                                     henri matisse    1869   1954   85
# 35                                       wade guyton    1972      0   50
# 36                        thomas sidney cooper, r.a.    1803   1902   99
# 37                                   georges rouault    1871   1958   87
# 38                                      josef albers    1888   1976   88
# 39                                    robert mangold    1937      0   85
# 40                                        max hofler    1892   1963   71
# 41                                     lucio fontana    1899   1968   69
# 42                                      thomas moran    1837   1926   89
# 43                                       irving penn    1917   2009   92
# 44                                        franz marc    1880   1916   36
# 45                      maria helena vieira da silva    1908   1992   84
# 46                                     david hockney    1937      0   85
# 47                                    simeon solomon    1840   1905   65
# 48                                       tracey emin    1963      0   59
# 49                                        emil nolde    1867   1956   89
#
#     Alive?  popularity                                          Art Title  \
# 0        0      114000               La Terrasse ou Une terrasse à Grasse
# 1        0      212000                                        Crucifixión
# 2        0      475000                              Guitare pendue au mur
# 3        0      549000                                    Ondine. Acte II
# 4        1      106000                                        Butterflies
# 5        1       73200       Drawing: Voice of America - Portland, Oregon
# 6        0       36000                                            Annabel
# 7        0      348000                                         Bellini #5
# 8        0      276000                               Le Cirque: one plate
# 9        0     2410000                                 Scylla et Charybde
# 10       0       38600                          Grande Fête de la Rosière
# 11       1       54800                                       La Baigneuse
# 12       0      125000                                                NaN
# 13       0     3340000                                         Camouflage
# 14       0      687000                                      AUG. 31, 1999
# 15       1    16800000                               Figure Composition 2
# 16       0       82100                                     La coupe bleue
# 17       0       50100  Dick Hickock, murderer; and Perry Smith, murde...
# 18       0      441000                                Table and Telephone
# 19       1      278000             Aparecida (from Pictures of Aftermath)
# 20       0      253000             Etude de champignons (recto and verso)
# 21       0       28400                                   Men at a meeting
# 22       1       12600                                             Diesel
# 23       1       47800                   Untitled (The Misunderstood One)
# 24       0      122000                                          Der Krieg
# 25       0       20800                          Nature morte à la guitare
# 26       0      156000                                            Horizon
# 27       0     2410000                                      Trompe l'oeil
# 28       1       12800                        Two untitled works on paper
# 29       0     9040000  Smithsonian Institute - National Collection of...
# 30       0       87600   Green Landscape, Brimaston Hook, Pembrokeshire I
# 31       0      137000                             The Judgement of Paris
# 32       1       54800                                              Horse
# 33       0      475000                             Courtisanes et toreros
# 34       0      253000                        Figure devant tapa africain
# 35       1       90900                        Untitled (Action Sculpture)
# 36       0       13800                        Cattle and sheep in a field
# 37       0       44300                                             Carmen
# 38       0       88600                                                 EA
# 39       1      351000  Irregular Yellow Orange Area with a Drawn Ellipse
# 40       0       20700                                  Low tide, Chelsea
# 41       0      138000                                  Concetto spaziale
# 42       0       30800                                     Indian Retreat
# 43       0      208000                    Callot Swallow-tail Dress, 1974
# 44       0       47600                  Drei Pferde mit abstrakten Formen
# 45       0       24600                                         Sans titre
# 46       1      190000                              Henry and Christopher
# 47       0      461000                               The golden headdress
# 48       1       33900                                     Trust Yourself
# 49       0       42800                                    Hamburger Hafen
#
#      DoC Currency        price  low_estimate  high_estimate  Sold  \
# 0      0      USD  19570000.00     5000000.0      8000000.0     1
# 1   1961      USD    273125.00      250000.0       375000.0     1
# 2   1927      USD   1215000.00     1000000.0      2000000.0     1
# 3      0      USD      7812.50        2500.0         3750.0     1
# 4   1998      USD    112500.00       70000.0        90000.0     1
# 5   1975      USD     17187.50        8750.0        12500.0     1
# 6      0      USD     96875.00       75000.0       100000.0     1
# 7      0      USD     21250.00       10000.0        15000.0     1
# 8      0      USD     31250.00       25000.0        35000.0     1
# 9   1970      USD     93125.00      100000.0       150000.0     1
# 10     0      USD      2031.25        1000.0         1500.0     1
# 11  1990      USD    230500.00      200000.0       300000.0     1
# 12     0      USD     21875.00       12500.0        18750.0     1
# 13  1986      USD    187500.00      120000.0       180000.0     1
# 14  1999      USD    715937.50      562500.0       812500.0     1
# 15  2008      USD    420500.00       60000.0        80000.0     1
# 16  1937      USD    185000.00      180000.0       250000.0     1
# 17     0      USD     25000.00       25000.0        35000.0     1
# 18  1942      USD     25000.00       30000.0        50000.0     1
# 19  1998      USD      9375.00       12000.0        18000.0     1
# 20     0      USD      6875.00        3000.0         5000.0     1
# 21     0      USD     23437.50       31250.0        43750.0     1
# 22  2003      USD     43750.00       15000.0        20000.0     1
# 23  1986      USD    295937.50      150000.0       225000.0     1
# 24     0      USD    295937.50       62500.0        93750.0     1
# 25     0      USD     58275.00       52500.0        73500.0     1
# 26  1973      USD     43562.50       25000.0        37500.0     1
# 27  1950      USD    189062.50       62500.0       100000.0     1
# 28  2007      USD       750.00        1000.0         2000.0     1
# 29     0      USD       750.00        1000.0         1500.0     1
# 30     0      USD     20312.50        8750.0        12500.0     1
# 31     0      USD     14843.75        7500.0        10000.0     1
# 32  2003      USD    591000.00      500000.0       700000.0     1
# 33     0      USD   1510937.50     1125000.0      1500000.0     1
# 34  1935      USD      6250.00        6000.0         8000.0     1
# 35  2005      USD     93750.00       80000.0       120000.0     1
# 36     0      USD      8593.75        5000.0         7500.0     1
# 37     0      USD     21875.00       12500.0        18750.0     1
# 38     0      USD      2375.00         800.0         1200.0     1
# 39  1987      USD    265625.00      187500.0       250000.0     1
# 40     0      USD      1875.00         750.0         1000.0     1
# 41  1959      USD     14175.00       15000.0        22500.0     1
# 42     0      USD     62500.00       70000.0       100000.0     1
# 43     0      USD     81250.00       20000.0        30000.0     1
# 44  1913      USD    378125.00       62500.0       100000.0     1
# 45     0      USD     36750.00       10500.0        15750.0     1
# 46  1973      USD    234375.00      225000.0       312500.0     1
# 47     0      USD      7500.00        5000.0         7500.0     1
# 48  2012      USD     56250.00       43750.0        56250.0     1
# 49     0      USD     68750.00       80000.0       120000.0     1
#
#     Est Accuracy                Dimentions  close date  \
# 0              1       (125.3 x 134.4 cm.)        2019
# 1              0        (190.2 x 237.5cm.)        2014
# 2              0         (27.1 x 35.2 cm.)        2019
# 3              1            (32.7 x 25cm.)        2021
# 4              1  (55.8 x 38.1 x 30.4 cm.)        2014
# 5              1        (137.7 x 101.7cm.)        2014
# 6              0           (33 x 24.1 cm.)        2021
# 7              1          (1497 x 973 mm.)        2021
# 8              0           (425 x 324 mm.)        2018
# 9             -1           (45 x 38.6 cm.)        2015
# 10             1           (46 x 61.2 cm.)        2015
# 11             0  (30.5 x 50.8 x 22.9 cm.)        2012
# 12             1             (452 x 620mm)        2019
# 13             1         (50.8 x 40.6 cm.)        2019
# 14             0              (46 x 61cm.)        2018
# 15             1         (127 x 116.8 cm.)        2018
# 16             0           (24.3 x 35 cm.)        2015
# 17            -1          (15.2 x 15.2cm.)        2014
# 18            -1       (61 cm. x 46.4 cm.)        2018
# 19            -1       (152.4 x 121.9 cm.)        2020
# 20             1           (25.7 x 33 cm.)        2021
# 21            -1           (36.2 x 26 cm.)        2021
# 22             1       (139.7 x 100.3 cm.)        2015
# 23             1        (243.5 x 182.5cm.)        2018
# 24             1             (and similar)        2017
# 25             0        (14 7/8 x 11¼ in.)        2013
# 26             1          (57.3 x 78.3cm.)        2012
# 27             1         (33.3 x 24.5 cm.)        2012
# 28            -1           (26 x 17.8 cm.)        2019
# 29            -1           (762 x 522 mm.)        2017
# 30             1           (54 x 75.6 cm.)        2013
# 31             1           (61 x 55.8 cm.)        2012
# 32             0    (98.4 x 94 x 50.8 cm.)        2020
# 33             1         (50.2 x 65.7 cm.)        2018
# 34             0           (533 x 435 mm.)        2018
# 35             0       (110 x 60 x 80 cm.)        2015
# 36             1         (42.6 x 53.4 cm.)        2014
# 37             1         (51.8 x 36.9 cm.)        2017
# 38             1           (260 x 352 mm.)        2021
# 39             1            (134 x 101cm.)        2019
# 40             1           (33 x 40.6 cm.)        2012
# 41            -1             (12 x 9.5cm.)        2022
# 42            -1           (78.7 x 33 cm.)        2015
# 43             1            (52 x 45.8cm.)        2015
# 44             1         (12.1 x 15.3 cm.)        2014
# 45             1            (8¼ x 10¼ in.)        2013
# 46             0          (35.4 x 43.2cm.)        2019
# 47             1         (22.2 x 19.3 cm.)        2018
# 48             1         (28 x 118 x 5cm.)        2016
# 49            -1           (30 x 46.8 cm.)        2018
#
#                                         Auction Title
# 0           IMPRESSIONIST AND MODERN ART EVENING SALE
# 1         POST-WAR & CONTEMPORARY ART EVENING AUCTION
# 2           IMPRESSIONIST AND MODERN ART EVENING SALE
# 3      First Open: Post-War & Contemporary Art Online
# 4       POST-WAR & CONTEMPORARY ART AFTERNOON SESSION
# 5                       POST-WAR AND CONTEMPORARY ART
# 6                         MODERN BRITISH ART DAY SALE
# 7                                Contemporary Edition
# 8                             Marc Chagall: Le Cirque
# 9                 IMPRESSIONIST/MODERN WORKS ON PAPER
# 10            IMPRESSIONIST/MODERN & PICASSO CERAMICS
# 11                                LATIN AMERICAN SALE
# 12  TOPOGRAPHICAL PICTURES INCLUDING SELECTIONS FR...
# 13      POST-WAR AND CONTEMPORARY ART MORNING SESSION
# 14          POST WAR AND CONTEMPORARY ART DAY AUCTION
# 15    POST-WAR AND CONTEMPORARY ART AFTERNOON SESSION
# 16  IMPRESSIONIST AND MODERN DAY SALE INCLUDING PR...
# 17                                        PHOTOGRAPHS
# 18                                American Art Online
# 19                                     Christie's 100
# 20  Matisse on Paper: Prints & Drawings from the E...
# 21                        MODERN BRITISH ART DAY SALE
# 22   POST-WAR AND CONTEMPORARY ART DAY SALE SESSION I
# 23          POST WAR AND CONTEMPORARY ART DAY AUCTION
# 24                               PRINTS AND MULTIPLES
# 25                     ART IMPRESSIONNISTE ET MODERNE
# 26                      POST-WAR AND CONTEMPORARY ART
# 27                IMPRESSIONIST/MODERN WORKS ON PAPER
# 28                                  On Paper | Online
# 29                               Contemporary Edition
# 30              MODERN BRITISH AND IRISH ART DAY SALE
# 31                      PETER LANGAN: A LIFE WITH ART
# 32                                 LATIN AMERICAN ART
# 33          IMPRESSIONIST AND MODERN ART EVENING SALE
# 34                                     Modern Edition
# 35   POST-WAR AND CONTEMPORARY ART DAY SALE SESSION I
# 36              VICTORIAN & BRITISH IMPRESSIONIST ART
# 37            IMPRESSIONIST AND MODERN WORKS ON PAPER
# 38  A Graphic Dialogue: Prints from the Collection...
# 39          POST-WAR AND CONTEMPORARY ART DAY AUCTION
# 40                                    THE LONDON SALE
# 41   First Open: Post-War and Contemporary Art Online
# 42                                       AMERICAN ART
# 43                                  20/21 PHOTOGRAPHS
# 44                IMPRESSIONIST/MODERN WORKS ON PAPER
# 45                                   ART CONTEMPORAIN
# 46          POST-WAR AND CONTEMPORARY ART DAY AUCTION
# 47  VICTORIAN PRE-RAPHAELITE & BRITISH IMPRESSIONI...
# 48          POST-WAR AND CONTEMPORARY ART DAY AUCTION
# 49  THE COLLECTION OF PEGGY AND DAVID ROCKEFELLER:...

# %%
Popularity_df.drop("Artist", axis=1, inplace=True)
Popularity_df.drop("Art Title", axis=1, inplace=True)
Popularity_df.drop("Currency", axis=1, inplace=True)
Popularity_df.drop("Dimentions", axis=1, inplace=True)
Popularity_df.drop("Auction Title", axis=1, inplace=True)

# %%
Popularity_df.head()
# Out:
#    Birth  Death  Age  Alive?  popularity   DoC       price  low_estimate  \
# 0   1867   1947   80       0      114000     0  19570000.0     5000000.0
# 1   1930   1998   68       0      212000  1961    273125.0      250000.0
# 2   1881   1973   92       0      475000  1927   1215000.0     1000000.0
# 3   1936   2008   72       0      549000     0      7812.5        2500.0
# 4   1929      0   93       1      106000  1998    112500.0       70000.0
#
#    high_estimate  Sold  Est Accuracy  close date
# 0      8000000.0     1             1        2019
# 1       375000.0     1             0        2014
# 2      2000000.0     1             0        2019
# 3         3750.0     1             1        2021
# 4        90000.0     1             1        2014

# %%
corrMatrix = Popularity_df.corr()
sn.set(rc = {'figure.figsize':(15,8)})
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# # Sales per year

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.hist(ArtInfo["close date"],bins = 21, label = 'Artwork Prices',
        histtype='bar', ec='black', color = "steelblue")
ax.set_title("Artworks Sold Per year Pulled from a Random Sample" , fontsize = 25)
ax.set_xlabel("Years", fontsize = 20)
ax.set_ylabel("# of Artworks", fontsize = 20)
ax.legend(loc = "upper left", prop={"size": 15})

plt.show(fig)

# %% [markdown]
# ## Most popular Artists by frequency of Sales

# %%
Artist_Count = ArtInfo['Artist'].value_counts(ascending=True)

# %%
Artist_Count_Dict = Artist_Count.to_dict()

# %%
smallest = Artist_Count.nsmallest(10).to_dict()

# %%
largest = Artist_Count.nlargest(10).to_dict()
names = list(largest.keys())
values = list(largest.values())

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
fig.tight_layout(pad=6.0)

ax.bar(names, values, label = 'Works sold from sample')
ax.set_title("Most popular Artists by frequency of Sales" , fontsize = 25)
ax.set_xlabel("Artists", fontsize = 20)
ax.set_ylabel("Works sold from sample size", fontsize = 20)
ax.legend(loc = "upper right", prop={"size": 15})
